# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

for i in range(5):
    path= 'results/h2h4_d50_batch8192_LR0.100000_pass1_run10%d.csv'%i
    data = pd.read_csv(path).as_matrix()
    N = 500
    plt.plot(data[:N,0]*500, np.minimum(data[:N,1],data[:N,2]))
plt.xlabel('Iterations')
plt.ylabel('Parameter Error')
matplotlib.axes.Axes.ticklabel_format
plt.show()
